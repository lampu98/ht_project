# %% [markdown]
# ## Gender Recognition

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../raw_data/database.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                               text      name  \
# 0           0  My name is Vi. And I am 28 years old. I arrive...        Vi
# 1           1  Thank you for the opportunity to testify befor...  Beatrice
# 2           2  My sister and I were living in a village. We w...    Kavita
# 3           3  I grew up in a village of between 500 and 700 ...     Maria
# 4           4  I was living in a village, Karko, in the Nuba ...     Mende
#
#    year departure                        arrival             theme   latitude  \
# 0  2001  Vietnam                 American Samoa      Forced labour -14.354000
# 1  2005  Sri Lank                       Lebanon   Domestic slavery  33.900000
# 2  2004  Sri Lank                         India   Domestic slavery  24.071318
# 3  2005   Mexico                  United States   Domestic slavery  40.412044
# 4  2003    Sudan   ['Sudan ', 'United Kingdom ']       War slavery  16.865226
#
#     longitude date_slavery
# ...

# %%
data['name'][0]
# Out:
# 'Vi'

# %%
data['gender']= 0

# %% [markdown]
# > Using gender API: it will return the gender and accuracy of our names column

# %%
import requests

for i in range(500,502):
    url = f'https://gender-api.com/get?name={data.loc[i, "name"]}&country=IT&key=9q8h9wAqm3S4cj9qbt9PeyUokfoTqhE6QkXx'
    response = requests.get(url)
    gender = response.json()['gender']
    accuracy = response.json()['accuracy']
    data.loc[i, "gender"]= gender
    data.loc[i, "accuracy"]= accuracy
    print(data.loc[i,["gender", "accuracy"]])
# Out:
# gender      female
# accuracy      75.0
# Name: 500, dtype: object
# gender      female
# accuracy      94.0
# Name: 501, dtype: object

# %%
data[500:502]
# Out:
#      Unnamed: 0                                               text   name  \
# 500         500  I was trafficked from Nigeria two years ago. I...  Idora
# 501         501  It is only with the heart that one can see rig...   Jana
#
#      year departure          arrival                theme   latitude  \
# 500  2013  Nigeria   United Kingdom   Sexual exploitation  55.378051
# 501  2010  Nigeria         Slovenia   Sexual exploitation  46.054661
#
#      longitude date_slavery  gender  accuracy
# 500  -3.435973    2011-2013  female      75.0
# 501  14.493645          NaN  female      94.0

# %%
for i in range(400,500):
    url = f'https://gender-api.com/get?name={data.loc[i, "name"]}&country=IT&key=9q8h9wAqm3S4cj9qbt9PeyUokfoTqhE6QkXx'
    response = requests.get(url)
    gender = response.json()['gender']
    accuracy = response.json()['accuracy']
    data.loc[i, "gender"]= gender
    data.loc[i, "accuracy"]= accuracy
    print(data.loc[i,["gender", "accuracy"]])
# Out:
# gender      female
# accuracy      88.0
# Name: 400, dtype: object
# gender      male
# accuracy    97.0
# Name: 401, dtype: object
# gender      female
# accuracy      98.0
# Name: 402, dtype: object
# gender      unknown
# accuracy        0.0
# Name: 403, dtype: object
# gender      male
# accuracy    97.0
# Name: 404, dtype: object
# gender      female
# accuracy      75.0
# Name: 405, dtype: object
# gender      male
# accuracy    74.0
# Name: 406, dtype: object
# gender      female
# accuracy      75.0
# Name: 407, dtype: object
# gender      female
# accuracy      99.0
# Name: 408, dtype: object
# gender      female
# accuracy      51.0
# Name: 409, dtype: object
# gender      female
# accuracy      96.0
# Name: 410, dtype: object
# gender      female
# accuracy      96.0
# Name: 411, dtype: object
# gender      female
# accuracy      98.0
# Name: 412, dtype: object
# gender      female
# accuracy      60.0
# Name: 413, dtype: object
# gender      female
# accuracy      99.0
# ...

# %%
data[400:502]
# Out:
#      Unnamed: 0                                               text       name  \
# 400         400  I wanted to become a doctor when I was a kid. ...        Ika
# 401         401  I graduated from junior high school, I had no ...     Ismail
# 402         402  My mom didn’t work and my dad worked in the fi...      Janet
# 403         403  My parents were working but they found it very...   Joeychev
# 404         404  My mom’s job was sleeping with men for money. ...       Jose
# ..          ...                                                ...        ...
# 497         497  My name is Henriette Akofa. I come from Togo. ...  Henriette
# 498         498  Our boat was stealing fish from Indonesian wat...       Htay
# 499         499  When I was 16, my parents borrowed £5000 to pa...       Hung
# 500         500  I was trafficked from Nigeria two years ago. I...      Idora
# 501         501  It is only with the heart that one can see rig...       Jana
#
# ...

# %%
for i in range(502,600):
    url = f'https://gender-api.com/get?name={data.loc[i, "name"]}&country=IT&key=9q8h9wAqm3S4cj9qbt9PeyUokfoTqhE6QkXx'
    response = requests.get(url)
    gender = response.json()['gender']
    accuracy = response.json()['accuracy']
    data.loc[i, "gender"]= gender
    data.loc[i, "accuracy"]= accuracy

# %%
data
# 402         402  My mom didn’t work and my dad worked in the fi...      Janet
# 403         403  My parents were working but they found it very...   Joeychev
# 404         404  My mom’s job was sleeping with men for money. ...       Jose
# 405         405  When I was 15 years old, I helped my family by...      Khanh
# ..          ...                                                ...        ...
# 806         806  Hello. My name is Jin Hae Jo. I have been in t...        Jin
# 807         807  I left NK through On Sung, North Ham Kyung Pro...  Song-Hyun
# 808         808  My name is Jang Mi Kyung. I left my home town ...        NaN
# 809         809  I left NK in 2009 following a woman into China...    Keum-Ju
# 810         810  My name is Mi Kyung. I am working at a place w...        NaN
#
# ...

# %%
data_to_400 = pd.read_csv("../raw_data/data_to_400.csv")

# %%
data_to_400
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 396         396           396
# 397         397           397
# 398         398           398
# 399         399           399
# 400         400           400
#
#                                                   text      name    year  \
# 0    My name is Vi. And I am 28 years old. I arrive...        Vi  2001.0
# 1    Thank you for the opportunity to testify befor...  Beatrice  2005.0
# 2    My sister and I were living in a village. We w...    Kavita  2004.0
# 3    I grew up in a village of between 500 and 700 ...     Maria  2005.0
# 4    I was living in a village, Karko, in the Nuba ...     Mende  2003.0
# ..                                                 ...       ...     ...
# 396  I got married when I was eighteen. Six months ...       Eka  2011.0
# ...

# %%
data_to_810 = pd.concat([data_to_400, data_401_811]).drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])

# %%
data_to_810.to_csv("data_to_810.csv")

# %%
data.shape
# Out:
# (1358, 12)

# %%
for i in range(811,814):
    url = f'https://gender-api.com/get?name={data.loc[i, "name"]}&country=IT&key=FYyLrvjhy6U7r8hzxVMvbtMnU7R4BUFKmV7L'
    response = requests.get(url)
    gender = response.json()['gender']
    accuracy = response.json()['accuracy']
    data.loc[i, "gender"]= gender
    data.loc[i, "accuracy"]= accuracy

# %%
data[811:814]
# Out:
#      Unnamed: 0                                               text name  year  \
# 811         811  I was a technician at the clothing factory. Wh...   KH  2010
# 812         812  I came from xx county, Hamkyung province in NK...  Lee  2010
# 813         813  I was a merchant selling goods at XX city mark...  Kim  2010
#
#        departure                    arrival        theme  latitude  \
# 811  North Korea                     China   Trafficking  35.86166
# 812  North Korea                     China   Trafficking  35.86166
# 813  North Korea  ['China ', 'North Korea']  Trafficking  35.86166
#
#       longitude date_slavery gender  accuracy
# 811  104.195396    2003-2009   male      60.0
# 812  104.195396          NaN   male      80.0
# 813  104.195396    2002-2007   male      51.0

# %%
for i in range(809,1201):
    url = f'https://gender-api.com/get?name={data.loc[i, "name"]}&country=IT&key=FYyLrvjhy6U7r8hzxVMvbtMnU7R4BUFKmV7L'
    response = requests.get(url)
    gender = response.json()['gender']
    accuracy = response.json()['accuracy']
    data.loc[i, "gender"]= gender
    data.loc[i, "accuracy"]= accuracy

# %%
data[809:1201]
# Out:
#       Unnamed: 0                                               text     name  \
# 809          809  I left NK in 2009 following a woman into China...  Keum-Ju
# 810          810  My name is Mi Kyung. I am working at a place w...      NaN
# 811          811  I was a technician at the clothing factory. Wh...       KH
# 812          812  I came from xx county, Hamkyung province in NK...      Lee
# 813          813  I was a merchant selling goods at XX city mark...      Kim
# ...          ...                                                ...      ...
# 1196        1196  My expectations were that I would work in hous...     Mary
# 1197        1197  It’s like your dead…because you’re scared, bec...  Natasha
# 1198        1198  She told us to wait for a while.  Then she cam...     Anya
# 1199        1199  He said his name was Apo.  I was in hysterics....    Katia
# 1200        1200  I am not treated as a human being. I am depriv...     Mila
#
# ...

# %%
data_from_1201 = pd.read_csv("../raw_data/data_from_1201.csv")
data_from_1201.set_index('Unnamed: 0',inplace = True)

# %%
data_from_1201
# Out:
#                                                          text      name  year  \
# Unnamed: 0
# 1201        I got used to getting beaten up, so I used to ...    Stella  2010
# 1202        I had a difficult time. I managed really bad b...   Rukmini  2010
# 1203        There was a time I was about to kill myself be...     Grace  2010
# 1204        My name is melody I’m from Nigeria. I lost my ...    Melody  2012
# 1205        Before this, I hadn’t come across much evil in...     Tanya  2017
# ...                                                       ...       ...   ...
# 1353        My name is Suleiman Ali, I’m Sudanese. I want ...  Suleiman  2020
# 1354        In Nigeria, it was difficult to make a living....     Shola  2020
# 1355        My name is Seif Eldein. I’m 24 years old, from...      Seif  2020
# 1356        I was begging and sleeping in the street behin...      Rita  2020
# 1357        I lived with my mother and father and they wer...      Nora  2020
#
# ...

# %%
data.drop(columns = "Unnamed: 0", inplace = True)

# %%
data_401_1201 =data[401:1201]

# %%
data_to_400
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 396         396           396
# 397         397           397
# 398         398           398
# 399         399           399
# 400         400           400
#
#                                                   text      name    year  \
# 0    My name is Vi. And I am 28 years old. I arrive...        Vi  2001.0
# 1    Thank you for the opportunity to testify befor...  Beatrice  2005.0
# 2    My sister and I were living in a village. We w...    Kavita  2004.0
# 3    I grew up in a village of between 500 and 700 ...     Maria  2005.0
# 4    I was living in a village, Karko, in the Nuba ...     Mende  2003.0
# ..                                                 ...       ...     ...
# 396  I got married when I was eighteen. Six months ...       Eka  2011.0
# ...

# %%
data_401_1201
# Out:
#                                                    text      name  year  \
# 401   I graduated from junior high school, I had no ...    Ismail  2012
# 402   My mom didn’t work and my dad worked in the fi...     Janet  2011
# 403   My parents were working but they found it very...  Joeychev  2011
# 404   My mom’s job was sleeping with men for money. ...      Jose  2012
# 405   When I was 15 years old, I helped my family by...     Khanh  2012
# ...                                                 ...       ...   ...
# 1196  My expectations were that I would work in hous...      Mary  2016
# 1197  It’s like your dead…because you’re scared, bec...   Natasha  2017
# 1198  She told us to wait for a while.  Then she cam...      Anya  2017
# 1199  He said his name was Apo.  I was in hysterics....     Katia  2017
# 1200  I am not treated as a human being. I am depriv...      Mila  2010
#
#          departure          arrival                                theme  \
# ...

# %%
data_from_1201
# Out:
#                                                          text      name  year  \
# Unnamed: 0
# 1201        I got used to getting beaten up, so I used to ...    Stella  2010
# 1202        I had a difficult time. I managed really bad b...   Rukmini  2010
# 1203        There was a time I was about to kill myself be...     Grace  2010
# 1204        My name is melody I’m from Nigeria. I lost my ...    Melody  2012
# 1205        Before this, I hadn’t come across much evil in...     Tanya  2017
# ...                                                       ...       ...   ...
# 1353        My name is Suleiman Ali, I’m Sudanese. I want ...  Suleiman  2020
# 1354        In Nigeria, it was difficult to make a living....     Shola  2020
# 1355        My name is Seif Eldein. I’m 24 years old, from...      Seif  2020
# 1356        I was begging and sleeping in the street behin...      Rita  2020
# 1357        I lived with my mother and father and they wer...      Nora  2020
#
# ...

# %% [markdown]
# > Concatenate all dataframes together

# %%
final_dataframe=pd.concat([data_to_400, data_401_1201, data_from_1201]).drop(columns=["Unnamed: 0","Unnamed: 0.1"])

# %%
final_dataframe.to_csv("final_dataframe.csv")

# %% [markdown]
# End of notebook
