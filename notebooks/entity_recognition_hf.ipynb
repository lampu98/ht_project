# %%
# !pip install transformers

# %%
import pandas as pd

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# %%
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = "My name is Wolfgang and I live in Berlin"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.99901396, 'index': 4, 'word': 'Wolfgang', 'start': 11, 'end': 19}, {'entity': 'B-LOC', 'score': 0.999645, 'index': 9, 'word': 'Berlin', 'start': 34, 'end': 40}]

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
# 'Colab Notebooks'	     IMG_20200412_140702.jpg
#  database.csv		     IMG_20200612_194718.jpg
#  IMG_20191112_150822.jpg     IMG_20200616_160416.jpg
#  IMG_20191112_204056.jpg     IMG_20200621_173911.jpg
#  IMG_20191112_214909.jpg     IMG_20200626_212204.jpg
#  IMG_20191113_095615.jpg     IMG_20200627_135244.jpg
#  IMG_20191119_174838.jpg     IMG_20200701_200342.jpg
#  IMG_20191221_150212.jpg     IMG_20200709_172636.jpg
#  IMG_20191223_175311.jpg     IMG_20200709_180942.jpg
#  IMG_20191229_195930.jpg     IMG_20200712_172900.jpg
#  IMG_20200102_192602.jpg     IMG_20200712_173023.jpg
#  IMG_20200202_134256.jpg     IMG_20200713_142712.jpg
#  IMG_20200214_203307_1.jpg   IMG_20200715_191752_1.jpg
#  IMG_20200214_203335.jpg     IMG_20200901_193251.jpg
#  IMG_20200214_203357_1.jpg   IMG_20201108_195920.jpg
#  IMG_20200214_212005_1.jpg   IMG_20201209_140403.jpg
#  IMG_20200310_140345.jpg     SAVE_20200815_221015.jpg
#  IMG_20200313_163452.jpg     Tenerife.gmap
#  IMG_20200317_164303.jpg

# %%
df = pd.read_csv('database.csv')
df.head()
# Out:
#    Unnamed: 0  ... date_slavery
# 0           0  ...          NaN
# 1           1  ...          NaN
# 2           2  ...    2002-2004
# 3           3  ...    1976-1981
# 4           4  ...    1994-2000
#
# [5 rows x 10 columns]

# %%
all_list
# Out:
# [(0,
#   [{'end': 12,
#     'entity': 'B-PER',
#     'index': 4,
#     'score': 0.91551983,
#     'start': 11,
#     'word': 'V'},
#    {'end': 59,
#     'entity': 'B-LOC',
#     'index': 17,
#     'score': 0.999274,
#     'start': 51,
#     'word': 'American'},
#    {'end': 65,
#     'entity': 'I-LOC',
#     'index': 18,
#     'score': 0.99838144,
#     'start': 60,
#     'word': 'Samoa'},
#    {'end': 114,
#     'entity': 'B-MISC',
#     'index': 29,
#     'score': 0.9995297,
#     'start': 104,
#     'word': 'Vietnamese'},
#    {'end': 200,
#     'entity': 'B-ORG',
#     'index': 46,
#     'score': 0.97345614,
#     'start': 196,
#     'word': 'Tour'},
#    {'end': 208,
#     'entity': 'I-ORG',
#     'index': 47,
#     'score': 0.9946268,
#     'start': 201,
#     'word': 'Company'},
#    {'end': 211,
#     'entity': 'I-ORG',
#     'index': 48,
#     'score': 0.9616108,
#     'start': 209,
#     'word': '12'},
#    {'end': 251,
#     'entity': 'B-LOC',
#     'index': 59,
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import pickle
def load_pickle():
  if not os.path.exists('test.obj'):
    return [] 
  with open('test.obj', 'rb') as fp:
    b = pickle.load(fp)
  return b

def save_pickle(file):
  with open('test.obj', 'wb') as fp:
    pickle.dump(file, fp)

def append_pickle(list_element):
  all_list = load_pickle()
  for i in list_element:
    all_list.append(i)
  save_pickle(all_list)

def get_last_element():
  list2 = load_pickle()
  if len(list2)>0:
    return list2[-1][0]
  return 0

# %%
from tqdm.notebook import tqdm

# %%
ner_results
# Out:
# [{'end': 12,
#   'entity': 'B-PER',
#   'index': 4,
#   'score': 0.91551983,
#   'start': 11,
#   'word': 'V'},
#  {'end': 59,
#   'entity': 'B-LOC',
#   'index': 17,
#   'score': 0.999274,
#   'start': 51,
#   'word': 'American'},
#  {'end': 65,
#   'entity': 'I-LOC',
#   'index': 18,
#   'score': 0.99838144,
#   'start': 60,
#   'word': 'Samoa'},
#  {'end': 114,
#   'entity': 'B-MISC',
#   'index': 29,
#   'score': 0.9995297,
#   'start': 104,
#   'word': 'Vietnamese'},
#  {'end': 200,
#   'entity': 'B-ORG',
#   'index': 46,
#   'score': 0.97345614,
#   'start': 196,
#   'word': 'Tour'},
#  {'end': 208,
#   'entity': 'I-ORG',
#   'index': 47,
#   'score': 0.9946268,
#   'start': 201,
#   'word': 'Company'},
#  {'end': 211,
#   'entity': 'I-ORG',
#   'index': 48,
#   'score': 0.9616108,
#   'start': 209,
#   'word': '12'},
#  {'end': 251,
#   'entity': 'B-LOC',
#   'index': 59,
#   'score': 0.99950737,
#   'start': 249,
#   'word': 'US'},
#  {'end': 363,
#   'entity': 'I-ORG',
# ...

# %%
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
nlp = pipeline("ner", model=model, tokenizer=tokenizer)
entities = []
cpt = 0

for index, row in tqdm(df.iterrows()):
  ner_results = nlp(row['text'])
  for el in ner_results:
    el["line_id"]=index

  entities+=ner_results

  #if index % 20==0:
  #  append_pickle(entities)
    
  cpt+=1
df_entities = pd.DataFrame(entities)
df_entities.to_csv("database_entities.csv")
# Out:
# 0it [00:00, ?it/s]

# %%
df_entities
# Out:
#      entity     score  index        word  start   end  line_id
# 0     B-PER  0.915520      4           V     11    12        0
# 1     B-LOC  0.999274     17    American     51    59        0
# 2     I-LOC  0.998381     18       Samoa     60    65        0
# 3    B-MISC  0.999530     29  Vietnamese    104   114        0
# 4     B-ORG  0.973456     46        Tour    196   200        0
# ..      ...       ...    ...         ...    ...   ...      ...
# 108  I-MISC  0.993045    240  Convention   1085  1095        9
# 109   B-LOC  0.999783    252       Haiti   1142  1147        9
# 110   B-LOC  0.999802    263       Haiti   1197  1202        9
# 111   B-LOC  0.999064    384       Haiti   1792  1797        9
# 112   B-LOC  0.473094    504        Port   2376  2380        9
#
# [113 rows x 7 columns]

# %%
list_of_entities = load_pickle()
