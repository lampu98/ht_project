# %%
my_list = ['I was sold for 4400 euros',
       'I was sold for 270 dollars',
       'I was sold for 10000 dollars',
       'I was bought for 10000 dollars']

# %%
df = pd.DataFrame({'word': ['I', 'was', 'sold', 'bought', 'for', '10000', '270', 'euros', 'dollars'],
                   'count': [4, 4, 3, 1, 4, 2, 1, 1, 3]})

# %%
df = pd.DataFrame({'word': ['I was sold for', 'I was bought for', '$10,000', '270 dollars', '4,400 euros'],
                   'count': [5, 1, 3, 1, 1]})

# %%
df
# Out:
#                word  count
# 0    I was sold for      5
# 1  I was bought for      1
# 2           $10,000      3
# 3       270 dollars      1
# 4       4,400 euros      1

# %%
# method 1: convert to dict 
data = dict(zip(df['word'].tolist(), df['count'].tolist()))

# method 2: convert to dict
data = df.set_index('word').to_dict()['count']

print(data)
# Out:
# {'I was sold for': 5, 'I was bought for': 1, '$10,000': 3, '270 dollars': 1, '4,400 euros': 1}

# %%
from wordcloud import WordCloud

wc = WordCloud(background_color="white",mode='RGB',width=800, height=400, max_words=200).generate_from_frequencies(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
dfn = ["[('408', '$'), ('4000', '$'), ('2000', '$'), ('200', '$')]",
       "[('200', '$')]", "[('2000', 'rupees'), ('45', '$')]",
       "[('5000', 'rupees'), ('100', '$'), ('200', '$')]",
       "[('40', '$'), ('48', '$'), ('300', '$'), ('28', '$'), ('20', '$'), ('20', '$')]",
       "[('9000', 'rupees'), ('500', 'rupees'), ('200', '$')]",
       "[('700', 'rupees'), ('6000', 'rupees'), ('15', '$'), ('130', '$')]",
       "[('300', 'rupees'), ('1500', 'rupees'), ('5000', 'rupees'), ('30', '$'), ('100', '$')]",
       "[('500', 'rupees'), ('10', '$')]", "[('35', 'cents')]",
       "[('8000', 'rupees'), ('400', 'rupees'), ('180', '$')]",
       "[('10,000', 'rupees'), ('300', 'rupees'), ('400', 'rupees'), ('200', '$')]",
       "[('30', 'cents')]", "[('300', '£')]", "[('60,000', '$')]",
       "[('3,000', '$'), ('200', '$')]", "[('20,000', '$')]",
       "[('900', '$')]", "[('12,000', '$')]", "[('100', '$')]",
       "[('12,000', '$'), ('10,000', '$'), ('3000', '$'), ('4000', '$')]",
       "[('200', '$')]",
       "[('2,700', '$'), ('5,000', '$'), ('30,000', '$'), ('100', '$'), ('30,000', '$')]",
       "[('136', '$')]", "[('39', '$')]", "[('10', '$')]",
       "[('100', '£')]", "[('5,000', '£')]",
       "[('12', 'cents'), ('20', '$')]", "[('500', '$')]",
       "[('1600', '$')]", "[('15,000', '£')]",
       "[('18,000', '$'), ('10,175', '£'), ('1,000', '$'), ('9,000', '$'), ('9,000', '$'), ('1,000', '$')]",
       "[('200', '$'), ('122', '£'), ('3,000', '$'), ('100', '$')]",
       "[('372', '£')]", "[('1,000', '$'), ('765', '£')]",
       "[('40,000', '£')]", "[('130', '$'), ('99', '£'), ('200', '$')]",
       "[('5000', 'yuan'), ('500', '£')]", "[('73', '$')]",
       "[('100', '$')]", "[('150', 'dollars')]", "[('1,673', 'Euros')]",
       "[('40,000', 'rupees'), ('20,000', 'rupees'), ('200', 'rupees'), ('230', 'rupees')]",
       "[('2000', 'rupees')]", "[('220', 'rupees')]", "[('1000', '£')]",
       "[('40', '$')]", "[('200', 'dollars')]", "[('3,117', '$')]",
       "[('1,818', '$')]", "[('408', '$'), ('163', '$'), ('250', '$')]",
       "[('4,052', '$'), ('78', '$')]", "[('10,000', '$')]",
       "[('2000', '£')]", "[('400', '$'), ('300', '$')]",
       "[('8,000', 'pesos'), ('1,800', '$'), ('500', '$'), ('150', '$')]",
       "[('100', '$'), ('25', '$'), ('150', '$'), ('30', '$')]",
       "[('500', '$'), ('500', '$'), ('500', '$'), ('50,000', '$'), ('50,000', '$'), ('50,000', '$')]",
       "[('75,000', '£')]", "[('300', '$')]", "[('750', '$')]",
       "[('72', '$')]", "[('16,000', 'yuan'), ('2,600', '$')]",
       "[('10,000', 'dollars')]", "[('2000', '$'), ('2000', '$')]",
       "[('250', '$')]", "[('570', '$')]",
       "[('20,000', 'yuan'), ('3,000', 'yuan'), ('2,500', '$'), ('400', '$')]",
       "[('3,500', 'euros'), ('4,400', '$')]", "[('2000', '$')]",
       "[('5,000', 'rupees'), ('360', 'rupees')]",
       "[('260', '$'), ('65', '$')]",
       "[('2000', 'euros'), ('2000', 'euros'), ('50', 'euros')]",
       "[('60', '$'), ('200', '$')]", "[('70', '$')]",
       "[('1000', 'dollars')]", "[('700', '£')]", "[('10', '£')]",
       "[('20', '$'), ('20', '$')]",
       "[('300', 'rupees'), ('13', 'rupees'), ('1,000', 'rupees'), ('2,000', 'rupees')]",
       "[('15,000', 'rupees'), ('40,000', 'rupees'), ('80', 'rupees'), ('1,000', 'rupees'), ('5,000', 'rupees'), ('20', 'rupees')]",
       "[('5,000', 'rupees'), ('25', 'rupees')]",
       "[('15,000', 'rupees'), ('80', 'rupees'), ('10,000', 'rupees'), ('5,000', 'rupees'), ('8,000', 'rupees')]",
       "[('2,000', 'rupees')]",
       "[('60,000', 'rupees'), ('40,000', 'rupees')]",
       "[('70,000', 'rupees'), ('40,000', 'rupees'), ('2,000', 'rupees')]",
       "[('200', 'rupees'), ('500', 'rupees')]", "[('45,000', 'rupees')]",
       "[('60,000', 'rupees'), ('200', 'rupees')]",
       "[('30,000', 'rupees'), ('3,000', 'rupees'), ('5,000', 'rupees'), ('150', 'rupees'), ('1,800', 'rupees'), ('6,000', 'rupees')]",
       "[('150', 'rupees'), ('250', 'rupees'), ('100', 'rupees'), ('3,000', 'rupees')]",
       "[('200', 'rupees'), ('50,000', 'rupees'), ('37,000', 'rupees')]",
       "[('200', '$'), ('1000', '$'), ('1000', '$'), ('20', '$'), ('20', '$'), ('70', '$'), ('50', '$')]",
       "[('1,000', '$')]", "[('40', '$')]", "[('700', '£')]",
       "[('6000', '$'), ('50', '$')]",
       "[('4,000', '$'), ('300', '$'), ('450', '$')]",
       "[('60,000', 'pesos'), ('1,260', '$')]", "[('20,000', '$')]",
       "[('300', 'euros')]", "[('3500', '$')]", "[('25', 'Euros')]",
       "[('270', '$')]", "[('50', '$')]", "[('182', '$'), ('176', '$')]",
       "[('50,00', '$')]", "[('4,600', '$')]",
       "[('1000', '$'), ('500', '$'), ('50', '$')]",
       "[('500', '$'), ('600', '$')]", "[('1000', '$'), ('2000', '$')]",
       "[('180', '$')]",
       "[('30,000', 'yen'), ('30,000', 'yen'), ('200', '$'), ('250', '$'), ('8000', '$'), ('685', '$')]",
       "[('1000', 'yen'), ('30,000', '$'), ('55,000', '$')]",
       "[('10,000', '$'), ('8000', '$')]",
       "[('30,000', '$'), ('10,000', '$')]", "[('75', 'rupees')]",
       "[('152', '$')]", "[('85,000', 'rupees'), ('880', '£')]",
       "[('6000', '$')]",
       "[('200', 'rupees'), ('200', 'rupees'), ('20', 'rupees'), ('110', 'rupees')]",
       "[('20,000', '$'), ('300', '$')]", "[('200', '$'), ('100', '$')]",
       "[('500', '$'), ('50', '$'), ('500', '$'), ('500', '$'), ('500', '$'), ('24,000', '$'), ('642,000', '$')]",
       "[('31', '$'), ('20', '$')]", "[('900', '$'), ('900', '$')]",
       "[('10', '$')]", "[('20', '$')]", "[('100', '$')]",
       "[('95', '$'), ('300', '$'), ('400', '$'), ('500', '$'), ('300', '$'), ('300', '$')]",
       "[('5000', '£')]",
       "[('260', '£'), ('220', '£'), ('40', '£'), ('1,000', '£'), ('60', '£')]",
       "[('1,350,000', 'USD'), ('1,000', '€'), ('1,350', '$'), ('5,000', '€'), ('50,000', '€')]",
       "[('12', '$'), ('200', '$'), ('300', '$'), ('500', '$')]",
       "[('1,200', 'USD'), ('1,300', 'USD'), ('290', 'USD'), ('580', 'USD')]",
       "[('70', 'USD'), ('30', '$'), ('70', '$')]", "[('1000', '$')]",
       "[('3000', 'dollars')]", "[('470', '$')]", "[('500', '$')]",
       "[('400', '$'), ('100', '$'), ('200', '$'), ('700', '$')]",
       "[('20,000', 'rupees'), ('40,000', 'rupees'), ('200', 'rupees'), ('200', 'rupees'), ('100', 'rupees'), ('400', '$'), ('600', '$')]",
       "[('500', 'rupees'), ('11', '$')]",
       "[('20,000', '$'), ('300', '$')]", "[('500', '$')]",
       "[('20', 'rupees'), ('1000', 'rupees'), ('20', '$')]",
       "[('1,000', '$'), ('2,000', '$')]", "[('150', '$'), ('78', '£')]",
       "[('200', '$'), ('100', '$')]",
       "[('20', 'dollars'), ('500,000', '$')]",
       "[('300', 'rupees'), ('1,000', 'rupees')]", "[('25', '$')]",
       "[('10,000', 'euros')]", "[('1000', '$')]", "[('150', '$')]",
       "[('22', '$'), ('15', '$')]",
       "[('500', 'euros'), ('1000', 'euros'), ('900', 'euros'), ('1000', 'euros'), ('30', 'euros'), ('100', '$'), ('650', '$'), ('1300', '$'), ('1000', '$'), ('15,000', '$'), ('2600', '$'), ('40', '$')]",
       "[('12,000', '$'), ('10,000', '$'), ('2000', '$')]",
       "[('15', 'cents'), ('10,000', '$')]",
       "[('12,000', '$'), ('30,000', '$'), ('20,000', '$'), ('3000', '$'), ('10,000', '$'), ('980', '$')]",
       "[('130', '$'), ('50', '$'), ('1300', '$'), ('12,000', '$'), ('1000', '$'), ('400', '$'), ('1000', '$'), ('40', '$')]",
       "[('400', '$')]", "[('2200', '$'), ('22', '$'), ('25', '$')]",
       "[('1000', '$')]", "[('1,000', 'USD'), ('1,000', '$')]",
       "[('400', '$'), ('500', '$')]", "[('700', '$'), ('5,000', '$')]",
       "[('300', '$')]", "[('20', '$')]", "[('82,000', 'rupees')]",
       "[('3,000', 'rupees')]",
       "[('3000', 'rupees'), ('20,000', 'rupees')]",
       "[('5,000', 'rupees')]",
       "[('1,500', 'rupees'), ('1,00,000', 'rupees'), ('30,000', 'rupees')]",
       "[('110', 'rupees'), ('400', 'rupees')]",
       "[('4,000', 'rupees'), ('1,00,000', 'rupees')]",
       "[('10,000', 'rupees')]", "[('100', 'rupees')]",
       "[('223', '$'), ('134', '$')]", "[('200', '£'), ('300', '£')]",
       "[('500', 'rupees')]",
       "[('10', 'dollars'), ('20', 'dollars'), ('400', '$')]",
       "[('25', '£')]", "[('5,000', 'yuan'), ('640', '$'), ('800', '$')]",
       "[('88,000', 'yuan'), ('14,000', '$')]",
       "[('1,000', 'yuan'), ('2,000', 'yuan'), ('159', '$')]",
       "[('75,000', '$')]", "[('40', 'USD'), ('6000', 'USD')]",
       "[('594', '$')]", "[('2,000', '$')]",
       "[('80', '$'), ('2,000', '$')]", "[('600', '$')]",
       "[('300', '$'), ('2,000', '$'), ('10', '$')]", "[('4,000', '£')]",
       "[('250', '£')]", "[('22,000', 'dollars')]",
       "[('400', '$'), ('192', '$')]", "[('302', '$')]", "[('280', '$')]",
       "[('400', '$'), ('400', '$'), ('400', '$')]",
       "[('206', '$'), ('247', '$'), ('247', '$')]", "[('21', '$')]",
       "[('370', '$')]",
       "[('45,000', '$'), ('13,000', '$'), ('45,000', '$')]",
       "[('148', '$')]",
       "[('1,000', 'euros'), ('6,500', '$'), ('1,225', '$'), ('2,200', '$')]",
       "[('2,000', 'dollars'), ('17,000', 'dollars')]", "[('5,00', '$')]",
       "[('6,000', '$'), ('1,600', '$'), ('5,000', '$')]",
       "[('10,000', 'yuan')]", "[('200', '$'), ('510', '$')]",
       "[('4,000', '$'), ('515', '$'), ('21,000', '$'), ('2,709', '$')]",
       "[('100', '$')]", "[('310', '$'), ('30', '$'), ('70', '$')]",
       "[('510', '$')]",
       "[('3,580', '$'), ('460', '$'), ('2,000', '$'), ('260', '$'), ('2,000', '$'), ('260', '$')]",
       "[('3,900', '$'), ('500', '$'), ('2,000', '$'), ('260', '$'), ('100', '$')]",
       "[('3,580', '$'), ('460', '$'), ('2,000', '$'), ('260', '$'), ('200', '$'), ('25', '$')]",
       "[('2,200', '$'), ('280', '$'), ('3,580', '$'), ('460', '$'), ('2,200', '$'), ('280', '$')]",
       "[('2,000', '$')]", "[('10', '$'), ('70', '$')]",
       "[('10,000', '$')]", "[('1,000', '$')]",
       "[('800', '$'), ('4,000', '$')]",
       "[('100', '$'), ('250', '$'), ('1,250', '$')]",
       "[('125,000', 'rupees'), ('1950', 'USD'), ('1950', '$')]",
       "[('300', '$')]", "[('3,500', '$'), ('33,000', '$')]",
       "[('4,000', '$')]", "[('2,000', '$')]", "[('10,000', '$')]",
       "[('35,000', '$'), ('3,400', '$')]", "[('36,000', '$')]",
       "[('28,300', '$')]", "[('36,000', '$')]", "[('36,400', '$')]",
       "[('40,000', '$')]", "[('40,000', '$')]", "[('35,000', '$')]",
       "[('35,000', '$')]", "[('22,000', '$')]", "[('35,000', '$')]",
       "[('30,000', '$')]", "[('250', '$')]", "[('2,500', '$')]",
       "[('80', '$')]",
       "[('2,200', '$'), ('280', '$'), ('3,580', '$'), ('460', '$')]",
       "[('3,740', '$'), ('480', '$')]",
       "[('21,000', '$'), ('2,709', '$'), ('56,987', '$'), ('7,300', '$'), ('160', '$'), ('20', '$')]",
       "[('3,580', '$'), ('460', '$'), ('2,600', '$'), ('330', '$'), ('1,230', '$'), ('3,580', '$'), ('460', '$')]",
       "[('100', '$'), ('40', '$')]",
       "[('3,480', '$'), ('450', '$'), ('2,770', '$')]",
       "[('100', '$'), ('15', '$'), ('40', '$'), ('3,000', '$'), ('390', '$'), ('580', '$'), ('75', '$')]",
       "[('2,000', '$'), ('260', '$'), ('3,580', '$'), ('460', '$')]",
       "[('3,580', '$'), ('465', '$')]", "[('6,500', '$')]",
       "[('48,', '$'), ('50', 'dollars'), ('3,000', 'pesos'), ('450', 'pesos'), ('1,000', 'pesos'), ('1,000', 'pesos'), ('70', '$'), ('46', '$'), ('60', '$'), ('48', '$'), ('50', '$'), ('300', '$'), ('28', '$'), ('35', '$'), ('75', '$')]",
       "[('100', '$'), ('100', '$'), ('500', '$')]", "[('200,000', '$')]",
       "[('35', '£'), ('35', '£'), ('35', '£')]",
       "[('100', '$'), ('250', '$'), ('1,250', '$')]", "[('150', '$')]",
       "[('3000', 'rupees')]", "[('100', '£')]",
       "[('5900', 'pesos'), ('220', '$'), ('136', '$')]",
       "[('35', '£'), ('35', '£'), ('35', '£')]",
       "[('12,000', '$'), ('300', '$'), ('600', '$')]",
       "[('12,000', 'dollars')]", "[('100', '$'), ('20,000', '$')]",
       "[('80', '$')]", "[('10,000', '$')]",
       "[('4,500', '$'), ('5,000', '$'), ('20,000', '$')]",
       "[('450', 'euros')]", "[('12,000', '$'), ('400', '$')]",
       "[('500,', '$'), ('200,', '$'), ('3,000', '$'), ('3,000', '$'), ('3,000', '$'), ('300', '$'), ('3,000', '$'), ('20', '$'), ('10', '$'), ('20', '$'), ('20', '$'), ('300', '$'), ('1,500', '$'), ('3,000', '$'), ('65,000', '$'), ('500', '$'), ('200', '$'), ('5,000', '$')]",
       "[('633', '$')]", "[('1,100', '£')]",
       "[('100,', '$'), ('100', '$'), ('200', '$')]",
       "[('99', '$'), ('99', '$'), ('350', '$')]",
       "[('550', '$'), ('40', '$')]", "[('3,000', '£')]",
       "[('500', '£')]", "[('1,650', '£'), ('1,200', '£')]",
       "[('200', '£')]", "[('10,000', 'pesos'), ('11', '$')]",
       "[('400', 'dollars')]",
       "[('5000', '$'), ('500', '$'), ('500', '$')]",
       "[('50,000', '$'), ('50,000', '$')]", "[('625', '$')]",
       "[('1,636', '$')]", "[('22,000', 'rupees')]",
       "[('15,000', 'rupees')]", "[('8,840', '$'), ('130', '$')]",
       "[('182', '$')]",
       "[('5,000', 'pesos'), ('10,000', 'pesos'), ('5,000', 'pesos'), ('107', '$'), ('214', '$')]",
       "[('1,000', '$')]", "[('50,000', 'rupees')]", "[('312', '$')]",
       "[('1,200', '$')]",
       "[('25,000', 'rupees'), ('420', 'USD'), ('100', 'rupees'), ('1.64', 'USD'), ('3000', 'rupees'), ('50', 'USD'), ('3000', 'rupees'), ('2000', 'rupees'), ('455', '$'), ('420', '$'), ('55', '$'), ('50', '$')]",
       "[('100', '$')]", "[('200', '$')]", "[('200', '$')]",
       "[('100', 'roubles'), ('135', '$')]",
       "[('1000', 'dollars'), ('000', 'dollars')]", "[('50', 'roubles')]",
       "[('200', 'dollars')]", "[('300', '$')]",
       "[('730', '$'), ('960', '$'), ('145', '$'), ('15', '$'), ('29', '$')]",
       "[('290', '$'), ('145', '$')]",
       "[('200,000', 'rupees'), ('2,665', '$')]",
       "[('2,990', '$'), ('290', '$'), ('130', '$'), ('145', '$'), ('29', '$'), ('44', '$'), ('175', '$')]",
       "[('260', '$'), ('290', '$'), ('160', '$'), ('10', '$'), ('3,325', '$')]",
       "[('1,460', '$'), ('220', '$'), ('175', '$'), ('100', '$'), ('350', '$')]",
       "[('730', '$'), ('220', '$'), ('650', '$'), ('115', '$')]",
       "[('1000', '$')]",
       "[('100', '$'), ('25', '$'), ('150', '$'), ('30', '$')]",
       "[('500', '$')]",
       "[('8,000', 'pesos'), ('1,800', '$'), ('500', '$'), ('150', '$')]",
       "[('400', '$'), ('300', '$')]", "[('20', '$')]",
       "[('30,', '$'), ('30', '$'), ('40', '$')]",
       "[('20', '$'), ('40', '$'), ('80', '$')]", "[('40', '$')]",
       "[('1,800', '$')]",
       "[('30,000', '$'), ('100', '$'), ('5,000', '$')]",
       "[('1000', '$'), ('500', '$')]", "[('2,700', '€')]",
       "[('50', '£')]", "[('20', '$')]", "[('200', '$'), ('300', '$')]",
       "[('25', '$')]", "[('3000', '$')]",
       "[('450', 'euros'), ('591', '$')]", "[('2,700', '€')]"]

# %%
type(dfn)
# Out:
# list

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

#convert list to string and generate
unique_string=(" ").join(dfn)
unique_string = unique_string.strip("\'")

wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
#plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()
