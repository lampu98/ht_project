# %%
import re
import pandas as pd

# %%
# I was sold for
# sell me for
# sold me for
# bought me for
# buy me for
# I was bought for

# %%
text = 'I was bought for $50 and for fifty $ also from for 11 ¢ not for 12 £ and for 13$ and for 12£. Then they wanted to buy me for $40. She sold me for 12 euros. I was sold for 300 pounds and then they tried to sell me for £40. They bought me for ¢5000 euros and ¢6 i have 2 trer and 500$ and also 12 rupees 300$. I was sold for 300 pounds and 30 dollars and 3£. They bought me for 5000 euros i have 2 trer and 500$ and also 12 rupees 300$'

# %%
for_currency_after_digit = re.findall('(for)\s(\d+)\s?(pounds|euros|rupees|Euros|dollars|cents|yen|yuan|takas|rubles|roubles|pesos|[\£|$|¢|€])',\
               text)

# %%
for_currency_after_digit
# Out:
# [('for', '11', '¢'),
#  ('for', '12', '£'),
#  ('for', '13', '$'),
#  ('for', '12', '£'),
#  ('for', '12', 'euros'),
#  ('for', '300', 'pounds'),
#  ('for', '300', 'pounds'),
#  ('for', '5000', 'euros')]

# %%
for_currency_before_digit = re.findall('(for)\s([\£|$|¢|€])\s?(\d+)', text)

# %%
for_currency_before_digit
# Out:
# [('for', '$', '50'),
#  ('for', '$', '40'),
#  ('for', '£', '40'),
#  ('for', '¢', '5000')]

# %%
for_currency_before_digit = [(c[0],c[2],c[1]) for c in for_currency_before_digit]

# %%
for_currency_before_digit
# Out:
# [('for', '50', '$'),
#  ('for', '40', '$'),
#  ('for', '40', '£'),
#  ('for', '5000', '¢')]

# %%
for_digit_and_currency_all = for_currency_before_digit + for_currency_after_digit

# %%
for_digit_and_currency_all
# Out:
# [('for', '50', '$'),
#  ('for', '40', '$'),
#  ('for', '40', '£'),
#  ('for', '5000', '¢'),
#  ('for', '11', '¢'),
#  ('for', '12', '£'),
#  ('for', '13', '$'),
#  ('for', '12', '£'),
#  ('for', '12', 'euros'),
#  ('for', '300', 'pounds'),
#  ('for', '300', 'pounds'),
#  ('for', '5000', 'euros')]

# %%
any_currency_after_digit = re.findall('(\d+)\s?(pounds|euros|rupees|Euros|dollars|cents|yen|yuan|takas|rubles|roubles|pesos|[\£$¢€])',\
               text)

# %%
any_currency_after_digit
# Out:
# [('11', '¢'),
#  ('12', '£'),
#  ('13', '$'),
#  ('12', '£'),
#  ('12', 'euros'),
#  ('300', 'pounds'),
#  ('5000', 'euros'),
#  ('500', '$'),
#  ('12', 'rupees'),
#  ('300', '$'),
#  ('300', 'pounds'),
#  ('30', 'dollars'),
#  ('3', '£'),
#  ('5000', 'euros'),
#  ('500', '$'),
#  ('12', 'rupees'),
#  ('300', '$')]

# %%
any_currency_before_digit = re.findall('([\£|$|¢|€])\s?(\d+)', text)

# %%
any_currency_before_digit = [(c[1],c[0]) for c in any_currency_before_digit]

# %%
any_currency_before_digit
# Out:
# [('50', '$'), ('40', '$'), ('40', '£'), ('5000', '¢'), ('6', '¢')]

# %%
any_mention_digit_and_currency = any_currency_before_digit + any_currency_after_digit

# %%
any_mention_digit_and_currency
# Out:
# [('50', '$'),
#  ('40', '$'),
#  ('40', '£'),
#  ('5000', '¢'),
#  ('6', '¢'),
#  ('11', '¢'),
#  ('12', '£'),
#  ('13', '$'),
#  ('12', '£'),
#  ('12', 'euros'),
#  ('300', 'pounds'),
#  ('5000', 'euros'),
#  ('500', '$'),
#  ('12', 'rupees'),
#  ('300', '$'),
#  ('300', 'pounds'),
#  ('30', 'dollars'),
#  ('3', '£'),
#  ('5000', 'euros'),
#  ('500', '$'),
#  ('12', 'rupees'),
#  ('300', '$')]

# %%
df = pd.read_csv('/Users/lega/code/QZKZ3/ht_project/raw_data/final_dataframe.csv', encoding='utf-8')

# %%
def extract_re_specific(text):
    ree1 = re.findall('(for)\s(\d+)\s?(pounds|euros|rupees|Euros|dollars|cents|yen|yuan|takas|rubles|roubles|pesos|[\£|$|¢|€])',\
               text)
    ree2 = re.findall('(for)\s([\£|$|¢|€])\s?(\d+)', text)
    ree2 = [(c[0],c[2],c[1]) for c in ree2]
    ree = ree1 + ree2
    return ree

# %%
df['bought_sold_for'] = df['text'].apply(extract_re_specific)

# %%
type(df['bought_sold_for'][0])
# Out:
# list

# %%
for index, elem in enumerate(df['bought_sold_for']):
    if elem:
        print(index, 'list not empty')
    else:
        print(index, 'list is empty')
# Out:
# 0 list is empty
# 1 list is empty
# 2 list is empty
# 3 list is empty
# 4 list is empty
# 5 list is empty
# 6 list is empty
# 7 list is empty
# 8 list is empty
# 9 list is empty
# 10 list is empty
# 11 list not empty
# 12 list is empty
# 13 list is empty
# 14 list is empty
# 15 list is empty
# 16 list is empty
# 17 list is empty
# 18 list is empty
# 19 list is empty
# 20 list is empty
# 21 list is empty
# 22 list is empty
# 23 list is empty
# 24 list is empty
# 25 list is empty
# 26 list is empty
# 27 list is empty
# 28 list is empty
# 29 list is empty
# 30 list is empty
# 31 list is empty
# 32 list is empty
# 33 list is empty
# 34 list is empty
# 35 list is empty
# 36 list not empty
# 37 list is empty
# 38 list is empty
# 39 list is empty
# 40 list is empty
# 41 list is empty
# 42 list is empty
# 43 list is empty
# 44 list is empty
# 45 list not empty
# 46 list is empty
# 47 list is empty
# 48 list is empty
# 49 list is empty
# 50 list not empty
# 51 list is empty
# ...

# %%
df['bought_sold_for'][543]
# Out:
# [('for', '500', '$')]

# %%
#append specific_all to dataframe as single column
#append general_add to dataframe as single column
#standardise currencies OPTIONAL - can do later
