# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
path = "raw_data/index_url.csv"
df=pd.read_csv(path)

# %%
response = requests.get("http://antislavery.ac.uk/items/show/2478")
html = response.text
soup = BeautifulSoup(html, features="html.parser")

# %%
pd.read_csv("/Users/fenice/code/QZKZ3/ht_project/database.csv")
# Out:
#       Unnamed: 0                                               text      name  \
# 0              0  My name is Vi. And I am 28 years old. I arrive...        Vi
# 1              1  Thank you for the opportunity to testify befor...  Beatrice
# 2              2  My sister and I were living in a village. We w...    Kavita
# 3              3  I grew up in a village of between 500 and 700 ...     Maria
# 4              4  I was living in a village, Karko, in the Nuba ...     Mende
# ...          ...                                                ...       ...
# 1353        1353  My name is Suleiman Ali, I’m Sudanese. I want ...  Suleiman
# 1354        1354  In Nigeria, it was difficult to make a living....     Shola
# 1355        1355  My name is Seif Eldein. I’m 24 years old, from...      Seif
# 1356        1356  I was begging and sleeping in the street behin...      Rita
# 1357        1357  I lived with my mother and father and they wer...      Nora
#
# ...

# %%
[125, 526, 527, 528, 530, 902, 912, 913, 914, 915, 917,918, 919, 920, 921, 973]
# Out:
# [125,
#  526,
#  527,
#  528,
#  530,
#  902,
#  912,
#  913,
#  914,
#  915,
#  917,
#  918,
#  919,
#  920,
#  921,
#  973]

# %%
params={"key":"aV8XxuZkdrNVbs6Y2JcS2WGhfJb3yFLe7cZZ","first_name":"Sandra"}
r=requests.get("https://gender-api.com/",params=params)

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/bv/2m8qf_b12pb0t66d5_p33nd00000gn/T/ipykernel_66111/661903446.py in <module>
# ----> 1 r.json()
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...
